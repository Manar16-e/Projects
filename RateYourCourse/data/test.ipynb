# %%
import pandas as pd
import re

# Load the CSV file
df = pd.read_csv('df_clean.csv')

# Display the column names
print(df.columns.tolist())
print(len(df))

# Display the first 5 rows in a nice table
display(df['schedule'].head())
# Out:
# ['url', 'title', 'volume', 'education', 'content', 'learning_outcome', 'literature', 'recommended_prereq', 'teaching_methods', 'workload', 'feedback_form', 'signup', 'exam_html', 'language', 'course_code', 'ects', 'level', 'duration', 'placement', 'schedule', 'capacity', 'study_board', 'department', 'faculty', 'course_coordinators', 'last_modified', 'term']
# 792
# 0    A
# 1    C
# 2    C
# 3    A
# 4    A
# Name: schedule, dtype: object

# %%
#def ()
print(len("Volume 2025/2026_Block 1"))
# Out:
# 24

# %%
def clean_term(val):
    if pd.isna(val):
        return val
    val_str = str(val) 
    first_year = str(val_str)[9:11]
    second_year = str(val_str)[14:16]
    if len(val_str)==24:
        block = "B"+str(val_str)[-1]
    elif "Summer" in val_str and not "Blok" in val_str:
        block = "S"
    else:
        block = ""
    return "s"+first_year+"/"+second_year+block

for orig, cleaned in zip(df['term'], df['term'].apply(clean_term)):
    print(f"Original: {orig} -> Cleaned: {cleaned}")
df['term'] = df['term'].apply(clean_term)
# Out:
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer Block 5 - Week 27-35 -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer Block 5 - Week 27-35 -> Cleaned: s25/26S
# Original: Volume 2025/2026_Block 3 And Block 4 -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 3 And Block 4 -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Spring -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 3 And Block 4 -> Cleaned: s24/25
# Original: Volume 2024/2025_Spring -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 3 And Block 4 -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Summer The course will run full time for 3 weeks in August. At the beginning of the course a detailed study plan will be sent to all participants. -> Cleaned: s25/26S
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Summer The course will run full time for 3 weeks in August. At the beginning of the course a detailed study plan will be sent to all participants. -> Cleaned: s24/25S
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer Block 5 - Week 27-35 -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer Block 5 - Week 27-35 -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 3 And Block 4 -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 3 And Block 4 -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Spring -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 3 And Block 4 -> Cleaned: s24/25
# Original: Volume 2025/2026_Spring -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 3 And Block 4 -> Cleaned: s25/26
# Original: Volume 2025/2026_Summer The course will run full time for 3 weeks in August. At the beginning of the course a detailed study plan will be sent to all participants. -> Cleaned: s25/26S
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Summer The course will run full time for 3 weeks in August. At the beginning of the course a detailed study plan will be sent to all participants. -> Cleaned: s24/25S
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer Block 5 - Week 27-35 -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer Block 5 - Week 27-35 -> Cleaned: s25/26S
# Original: Volume 2025/2026_Block 3 And Block 4 -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 3 And Block 4 -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 3 And Block 4 -> Cleaned: s24/25
# Original: Volume 2024/2025_Spring -> Cleaned: s24/25
# Original: Volume 2025/2026_Spring -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 3 And Block 4 -> Cleaned: s25/26
# Original: Volume 2025/2026_Summer The course will run full time for 3 weeks in August. At the beginning of the course a detailed study plan will be sent to all participants. -> Cleaned: s25/26S
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Summer The course will run full time for 3 weeks in August. At the beginning of the course a detailed study plan will be sent to all participants. -> Cleaned: s24/25S
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer -> Cleaned: s24/25S
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1, Block 2, Block 3, Block 4 And Summer Block 5 - Week 27-35 -> Cleaned: s24/25S
# Original: Volume 2025/2026_Block 3 And Block 4 -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1, Block 2, Block 3, Block 4 And Summer Block 5 - Week 27-35 -> Cleaned: s25/26S
# Original: Volume 2024/2025_Block 3 And Block 4 -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 3 And Block 4 -> Cleaned: s24/25
# Original: Volume 2024/2025_Spring -> Cleaned: s24/25
# Original: Volume 2025/2026_Spring -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Volume 2025/2026_Block 3 And Block 4 -> Cleaned: s25/26
# Original: Volume 2025/2026_Summer The course will run full time for 3 weeks in August. At the beginning of the course a detailed study plan will be sent to all participants. -> Cleaned: s25/26S
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2024/2025_Summer The course will run full time for 3 weeks in August. At the beginning of the course a detailed study plan will be sent to all participants. -> Cleaned: s24/25S
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 1 -> Cleaned: s24/25B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 1 -> Cleaned: s25/26B1
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26
# Original: Volume 2025/2026_Block 4 -> Cleaned: s25/26B4
# Original: Volume 2024/2025_Block 4 -> Cleaned: s24/25B4
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Volume 2025/2026_Block 3 -> Cleaned: s25/26B3
# Original: Volume 2025/2026_Block 2 -> Cleaned: s25/26B2
# Original: Volume 2024/2025_Block 2 -> Cleaned: s24/25B2
# Original: Årgang 2024/2025_nan -> Cleaned: s24/25
# Original: Volume 2024/2025_Block 3 -> Cleaned: s24/25B3
# Original: Årgang 2025/2026_nan -> Cleaned: s25/26

# %%
def split_coordinator(row):
    match = re.match(r"\['(.*)\s\((.*)\)'\]", str(row))
    if match:
        return pd.Series({'course_coordinator_name': match.group(1), 'course_coordinator_id': match.group(2)})
    else:
        return pd.Series({'course_coordinator_name': None, 'course_coordinator_id': None})

split_df = df['course_coordinators'].apply(split_coordinator)
df['course_coordinator_name'] = split_df['course_coordinator_name']
df['course_coordinator_id'] = split_df['course_coordinator_id']

def single_course_coordinator(val):
    if pd.isna(val):
        return val
    match = re.match(r"(.*)\s\(.*", str(val))
    if match:
        return match.group(1)
    else:
        return val
    
df['course_coordinator_name'] = df['course_coordinator_name'].apply(single_course_coordinator)

def clean_schedule(val):
    if pd.isna(val):
        return val
    val_str = str(val)
    if len(val_str) == 2:
        return val_str[0]
    elif len(val_str) > 30:
        if "Summer" in val_str and not "Blok" in val_str:
            return "Summer"
        elif "Sommer" in val_str and not "Blok" in val_str:
            return "Summer"
        else:
            return "Other"
    else:
        return val_str

df['schedule'] = df['schedule'].apply(clean_schedule)

# Now df has two new columns
display(df[['course_coordinator_name', 'course_coordinator_id']].head())
# Out:
#   course_coordinator_name           course_coordinator_id
# 0       Panagiotis Karras    4-7566706645696e33707a336970
# 1         Amir Yehudayoff    4-6975816d486c7136737d366c73
# 2              Jacob Holm    4-6d646b7243676c316e7831676e
# 3       Panagiotis Karras    4-72636d6342666b306d7730666d
# 4        Troels Henriksen  5-71847871835074793e7b853e747b

# %%
def clean_brackets(val):
    if pd.isna(val):
        return val
    val_str = str(val)
    match = re.match(r"\['(.*)'\]", val_str)
    if match:
        return match.group(1)
    else:
        return val
df['faculty'] = df['faculty'].apply(clean_brackets)
df['department'] = df['department'].apply(clean_brackets)
df['study_board'] = df['study_board'].apply(clean_brackets)
# Display the cleaned DataFrame
display(df.head())
# Out:
#                                                 url  \
# 0  https://kurser.ku.dk/course/ndak15006u/2024-2025
# 1  https://kurser.ku.dk/course/ndaa09023u/2024-2025
# 2  https://kurser.ku.dk/course/ndaa09023u/2025-2026
# 3  https://kurser.ku.dk/course/ndak15006u/2025-2026
# 4  https://kurser.ku.dk/course/ndaa09013u/2025-2026
#
#                                                title            volume  \
# 0         NDAK15006U Advanced Computer Systems (ACS)  Volume 2024/2025
# 1  NDAA09023U Advanced Algorithms and Data Struct...  Volume 2024/2025
# 2  NDAA09023U Advanced Algorithms and Data Struct...  Volume 2025/2026
# 3         NDAK15006U Advanced Computer Systems (ACS)  Volume 2025/2026
# 4               NDAA09013U Advanced Programming (AP)  Volume 2025/2026
#
#                                            education  \
# 0                  MSc Programme in Computer Science
# 1  MSc Programme in Computer Science MSc Programm...
# 2  MSc Programme in Computer Science MSc Programm...
# 3                  MSc Programme in Computer Science
# 4                  MSc Programme in Computer Science
#
#                                              content  \
# 0  The overall purpose of this course is to offer...
# 1  Algorithms is about finding scalable solutions...
# 2  Algorithms is about finding scalable solutions...
# 3  The overall purpose of this course is to offer...
# 4  The purpose of this course is to provide pract...
#
#                                     learning_outcome  \
# 0  Knowledge to Describe the design of transactio...
# 1  Knowledge of Graph algorithms such as max flow...
# 2  Knowledge of Graph algorithms such as max flow...
# 3  Knowledge to Describe the design of transactio...
# 4  At course completion, the successful student w...
#
#                                literature  \
# 0  See Absalon when the course is set up.
# 1  See Absalon when the course is set up.
# 2  See Absalon when the course is set up.
# 3  See Absalon when the course is set up.
# 4  See Absalon when the course is set up.
#
#                                   recommended_prereq  \
# 0  - Basic principles of operating systems and/or...
# 1  It is assumed that the students are familiar w...
# 2  It is assumed that the students are familiar w...
# 3  - Basic principles of operating systems and/or...
# 4  Programming ability in at least two substantia...
#
#                                   teaching_methods  \
# 0                  Lectures and exercise sessions.
# 1                 A mix of lectures and exercises.
# 2                 A mix of lectures and exercises.
# 3                  Lectures and exercise sessions.
# 4  Lectures, mandatory assignments, exercise labs.
#
#                                             workload  ... schedule  \
# 0  {'Lectures': 42, 'Theory exercises': 70, 'Proj...  ...        A
# 1  {'Lectures': 36, 'Preparation': 82, 'Theory ex...  ...        C
# 2  {'Lectures': 36, 'Preparation': 82, 'Theory ex...  ...        C
# 3  {'Lectures': 42, 'Theory exercises': 70, 'Proj...  ...        A
# 4  {'Lectures': 29, 'Preparation': 124, 'Practica...  ...        A
#
#                                             capacity  \
# 0  No limitation – unless you register in the lat...
# 1  No limitation – unless you register in the lat...
# 2  No limitation – unless you register in the lat...
# 3  No limitation – unless you register in the lat...
# 4  No limitation – unless you register in the lat...
#
#                                        study_board  \
# 0  Study Board of Mathematics and Computer Science
# 1  Study Board of Mathematics and Computer Science
# 2  Study Board of Mathematics and Computer Science
# 3  Study Board of Mathematics and Computer Science
# 4  Study Board of Mathematics and Computer Science
#
#                        department             faculty  \
# 0  Department of Computer Science  Faculty of Science
# 1  Department of Computer Science  Faculty of Science
# 2  Department of Computer Science  Faculty of Science
# 3  Department of Computer Science  Faculty of Science
# 4  Department of Computer Science  Faculty of Science
#
#                                  course_coordinators            last_modified  \
# 0  ['Panagiotis Karras (4-7566706645696e33707a336...  Saved on the 05-07-2024
# 1  ['Amir Yehudayoff (4-6975816d486c7136737d366c7...  Saved on the 20-01-2025
# 2      ['Jacob Holm (4-6d646b7243676c316e7831676e)']  Saved on the 24-02-2025
# 3  ['Panagiotis Karras (4-72636d6342666b306d77306...  Saved on the 24-02-2025
# 4  ['Troels Henriksen (5-71847871835074793e7b853e...  Saved on the 01-05-2025
#
#        term course_coordinator_name           course_coordinator_id
# 0  s24/25B2       Panagiotis Karras    4-7566706645696e33707a336970
# 1  s24/25B2         Amir Yehudayoff    4-6975816d486c7136737d366c73
# 2  s25/26B2              Jacob Holm    4-6d646b7243676c316e7831676e
# 3  s25/26B2       Panagiotis Karras    4-72636d6342666b306d7730666d
# 4  s25/26B1        Troels Henriksen  5-71847871835074793e7b853e747b
#
# [5 rows x 29 columns]

# %%
df.to_csv('coordinator_split.csv', index=False)

# %%
print(single_course_coordinator("John Doe (12345)"))
# Out:
# John Doe

# %%
def unique_code_kuc_all_columns(df):
    """
    Returns a new DataFrame with all columns, keeping only the first occurrence of each unique code_kuc.
    """
    return df.drop_duplicates(subset=['course_code']).reset_index(drop=True)

# Example usage:
unique_df = unique_code_kuc_all_columns(df)
display(unique_df['course_coordinator_name'])
print(type(unique_df['course_coordinator_name'][0]))
# Out:
# 0                    Panagiotis Karras
# 1                      Amir Yehudayoff
# 2                     Troels Henriksen
# 3                        Stefan Sommer
# 4              Joanna Emilia Bergström
# 5                        Jens Petersen
# 6                       Amartya Sanyal
# 7                      Desmond Elliott
# 8                       Fritz Henglein
# 9                 Abraham George Smith
# 10                                None
# 11                 Srikanth Srinivasan
# 12                       Rasmus Heller
# 13                       Yongluan Zhou
# 14                       Rasmus Heller
# 15                       Rasmus Heller
# 16                       Rasmus Heller
# 17                    Alexander Schulz
# 18                         Ole Winther
# 19                        Boris Düdder
# 20                     Jakob Nordström
# 21            Melanie Ganz-Benjaminsen
# 22              Mikkel Vind Abrahamsen
# 23                 Cosmin Eugen Oancea
# 24                     Dmitriy Traytel
# 25                           Omry Ross
# 26                       Stefan Sommer
# 27                      Pernille Bjørn
# 28                     Valkyrie Savage
# 29    Jesper Riis-Vestergaard Sørensen
# 30                     Christina Lioma
# 31                      Kasper Hornbæk
# 32                       Teresa Hirzle
# 33                       Rasmus Heller
# 34             Kresten Lindorff-Larsen
# 35                     Dmitriy Traytel
# 36                  Daniel Hershcovich
# 37                        Robert Glück
# 38                       Sadegh Talebi
# 39                       Nirupam Gupta
# 40      Michael Baltzer Tønne Andersen
# 41            Melanie Ganz-Benjaminsen
# 42                 Daniel Lee Ashbrook
# 43                  Daniel Hershcovich
# 44                     Bulat Ibragimov
# 45                     Bulat Ibragimov
# 46                        Oswin Krause
# 47                       Sadegh Talebi
# 48                    Ken Friis Larsen
# 49                      Wouter Boomsma
# 50                        Robert Glück
# 51             Torben Ægidius Mogensen
# 52                 Cosmin Eugen Oancea
# 53                Thomas Wim Hamelryck
# 54                  Michael Kastoryano
# 55                          Jacob Holm
# 56           Thomas Troels Hildebrandt
# 57                            Hang Yin
# 58                     Christina Lioma
# 59                    Andrzej Filinski
# 60             Kim Steenstrup Pedersen
# 61                            Hang Yin
# 62                Irina Alex Shklovski
# 63                Tariq Osman Andersen
# 64                         Tijs Slaats
# 65                Thomas Philip Jensen
# 66                           Omry Ross
# 67                       Anders Aamand
# 68                 Daniel Lee Ashbrook
# 69             Joanna Emilia Bergström
# 70                      Serge Belongie
# 71                       Maria Maistro
# 72                      Kasper Hornbæk
# Name: course_coordinator_name, dtype: object
# <class 'str'>

# %%
unique_df.to_csv('unique_courses.csv', index=False)

# %%
print(unique_df['content'].str.len().max())
# Out:
# 3231

# %%
import pandas as pd

pd.set_option('display.max_rows', None)  # Show all rows
print(unique_df['schedule'])
# Out:
# 0                             A
# 1                             C
# 2                             A
# 3                             A
# 4                             C
# 5                             B
# 6                             C
# 7                             A
# 8                             B
# 9                         Other
# 10                          NaN
# 11                            A
# 12    Meetings with supervisor.
# 13                            C
# 14    Meetings with supervisor.
# 15    Meetings with supervisor.
# 16    Meetings with supervisor.
# 17                            C
# 18                            C
# 19                            C
# 20                            A
# 21                            C
# 22                            B
# 23                            C
# 24                            A
# 25                     B1 And D
# 26                            C
# 27                            A
# 28                            C
# 29                            B
# 30                            B
# 31                            C
# 32                            C
# 33    Meetings with supervisor.
# 34                            A
# 35                            C
# 36                            A
# 37                            A
# 38                        Other
# 39                        Other
# 40                            C
# 41                            A
# 42                            C
# 43                            B
# 44                            A
# 45                            C
# 46                            C
# 47                        Other
# 48                            A
# 49                            A
# 50                            C
# 51                            B
# 52                            C
# 53                            B
# 54                            B
# 55                            B
# 56                            B
# 57                            C
# 58                            B
# 59                            C
# 60                            A
# 61                            A
# 62                            B
# 63                        Other
# 64                            A
# 65                            B
# 66                        Other
# 67                            A
# 68                            A
# 69                            C
# 70                            C
# 71                            B
# 72                            B
# Name: schedule, dtype: object
